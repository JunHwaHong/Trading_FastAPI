# %%
import yfinance as yf


df = yf.download('AAPL', period='3y')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-06 00:00:00-05:00   73.447502   74.989998   73.187500   74.949997
# 2020-01-07 00:00:00-05:00   74.959999   75.224998   74.370003   74.597504
# 2020-01-08 00:00:00-05:00   74.290001   76.110001   74.290001   75.797501
# 2020-01-09 00:00:00-05:00   76.809998   77.607498   76.550003   77.407501
# 2020-01-10 00:00:00-05:00   77.650002   78.167503   77.062500   77.582497
# ...                               ...         ...         ...         ...
# 2022-12-27 00:00:00-05:00  131.380005  131.410004  128.720001  130.029999
# 2022-12-28 00:00:00-05:00  129.669998  131.029999  125.870003  126.040001
# 2022-12-29 00:00:00-05:00  127.989998  130.479996  127.730003  129.610001
# 2022-12-30 00:00:00-05:00  128.410004  129.949997  127.430000  129.929993
# 2023-01-03 00:00:00-05:00  130.279999  130.899994  124.169998  125.070000
#
#                             Adj Close     Volume
# Date
# ...

# %%
import sqlite3, config

connection = sqlite3.connect(config.DB_FILE)

cursor = connection.cursor()

# %%
cursor.execute("""
    SELECT * FROM stock_price
""")

rows = cursor.fetchall()
rows
# Out:
# []

# %%
import alpaca_trade_api as tradeapi
api = tradeapi.REST(config.API_KEY, config.SECRET_KEY, base_url=config.API_URL)
assets = api.list_assets()

# %%
assets[0]
# Out:
# Asset({   'class': 'us_equity',
#     'easy_to_borrow': False,
#     'exchange': 'OTC',
#     'fractionable': False,
#     'id': 'cc36a04d-20da-40dd-8ddc-2816c9c17048',
#     'maintenance_margin_requirement': 100,
#     'marginable': False,
#     'name': 'FFP Marketing Company, Inc. Common Stock',
#     'shortable': False,
#     'status': 'inactive',
#     'symbol': 'FFPM',
#     'tradable': False})

# %%
i = [x._raw['class'] for x in assets]

# %%
set(i)
# Out:
# {'crypto', 'us_equity'}

# %%
assets[0]._raw['class']
# Out:
# 'us_equity'

# %%
import config
from alpaca_trade_api.rest import REST, TimeFrame

api = REST(config.API_KEY, config.SECRET_KEY, base_url=config.API_URL)

# %%
import sqlite3, config
from alpaca_trade_api.rest import REST, TimeFrame

import datetime
start_str = "2023-01-01"
today = datetime.datetime.today()
today_str = today.strftime("%Y-%m-%d")

connection = sqlite3.connect(config.DB_FILE)
print(connection)
connection.row_factory = sqlite3.Row
cursor = connection.cursor()

cursor.execute("""
    SELECT id, symbol, name FROM stock
""")
rows = cursor.fetchall()

symbols = []
stock_dict = {}
for row in rows:
    symbol = row['symbol']
    symbols.append(symbol)
    stock_dict[symbol] = row['id']

# %%
import FinanceDataReader as fdr

# Ford(F), 1980-01-01 ~ 2019-12-30 (40년 데이터)
df = fdr.DataReader('AAPL', '2022-11-01')

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-11-01  155.080002  155.449997  149.130005  150.649994  150.400497
# 2022-11-02  148.949997  152.169998  145.000000  145.029999  144.789810
# 2022-11-03  142.059998  142.800003  138.750000  138.880005  138.650009
# 2022-11-04  142.089996  142.669998  134.380005  138.380005  138.380005
# 2022-11-07  137.110001  139.149994  135.669998  138.919998  138.919998
#
#                Volume
# Date
# 2022-11-01   80379300
# 2022-11-02   93604600
# 2022-11-03   97918500
# 2022-11-04  140814800
# 2022-11-07   83374600

# %%
import talib
import numpy as np

# %%
close = df['Close'].values

# %%
c= talib.SMA(close)

# %%
df = fdr.DataReader('AAPL', start_str, today_str)

# %%
for index, row in df.iterrows():
    pass

# %%
cursor.execute("""
    SELECT * FROM stock WHERE symbol= ?
""", ('AAPL',))

# %%
rows = cursor.fetchone()

# %%
rows
# Out:
# (10632, 'AAPL', 'Apple Inc. Common Stock', 'NASDAQ')

# %%
import sqlite3, config
connection = sqlite3.connect(config.DB_FILE)
# connection.row_factory = sqlite3.Row
cursor = connection.cursor()

cursor.execute("""
    SELECT * FROM strategy
""")
rows = cursor.fetchall()

# %%
rows
# Out:
# [(1, 'opening_range_breakout'),
#  (2, 'opening_range_breakdown'),
#  (3, 'bollinger_bands')]

# %%
for r in rows:
    print(r)
# Out:
# (1, 10621, '2022-10-03', 138.210007, 143.070007, 137.690002, 142.449997, 114311700.0, None, None, None)
# (2, 10621, '2022-10-04', 145.029999, 146.220001, 144.259995, 146.100006, 87830100.0, None, None, None)
# (3, 10621, '2022-10-05', 144.070007, 147.380005, 143.009995, 146.399994, 79471000.0, None, None, None)
# (4, 10621, '2022-10-06', 145.809998, 147.539993, 145.220001, 145.429993, 68402200.0, None, None, None)
# (5, 10621, '2022-10-07', 142.539993, 143.100006, 139.449997, 140.089996, 85925600.0, None, None, None)
# (6, 10621, '2022-10-10', 140.419998, 141.889999, 138.570007, 140.419998, 74899000.0, None, None, None)
# (7, 10621, '2022-10-11', 139.899994, 141.350006, 138.220001, 138.979996, 77033700.0, None, None, None)
# (8, 10621, '2022-10-12', 139.130005, 140.360001, 138.160004, 138.339996, 70433700.0, None, None, None)
# (9, 10621, '2022-10-13', 134.990005, 143.589996, 134.369995, 142.990005, 113224000.0, None, None, None)
# ...

# %%
import sqlite3, config
connection = sqlite3.connect(config.DB_FILE)
connection.row_factory = sqlite3.Row
cursor = connection.cursor()

cursor.execute("""
    SELECT id, symbol, name FROM stock
""")
rows = cursor.fetchall()

symbols = []
stock_dict = {}
for row in rows:
    symbol = row['symbol']
    symbols.append(symbol)
    stock_dict[symbol] = row['id']

# %%
chunk_size = 1

for i in range(0, len(symbols), chunk_size):
    symbol_chunk = symbols[i:i+chunk_size]

    barsets = dict()
    for t in symbol_chunk:
        barsets[t] = api.get_bars(t, TimeFrame.Day, start_str, today_str)

    # loop over the keys in the barsets dictionary
    for symbol in barsets:
        print(f"processing symbol {symbol}")
        # loop through each bar for the current symbol in the dictionary
        for bar in barsets[symbol]:
            stock_id = stock_dict[symbol]
            cursor.execute("""
                INSERT INTO stock_price (stock_id, date, open, high, low, close, volume)
                VALUES (?, ?, ?, ?, ?, ?, ?)
            """, (stock_id, bar.t.date(), bar.o, bar.h, bar.l, bar.c, bar.v))

# %%
chunk_size = 1
i = 0
symbol_chunk = symbols[i:i+chunk_size]
for symbol in symbol_chunk:
    df = fdr.DataReader(symbol, '2022-11-01')
    stock_idx = stock_dict[symbol]
    for index, row in df.iterrows():
        print(row.name.strftime("%Y-%m-%d"), row['Open'], row['High'], row['Low'], row['Close'], row['Volume'])
# Out:
# 2022-11-01 1891.25 1927.0 1886.040039 1889.52002 348900.0
# 2022-11-02 1862.790039 1884.72998 1771.319946 1778.180054 605900.0
# 2022-11-03 1849.0 1902.699951 1822.76001 1825.72998 742600.0
# 2022-11-04 1884.829956 1916.150024 1852.099976 1874.400024 438700.0
# 2022-11-07 1876.01001 1886.829956 1797.920044 1833.819946 433900.0
# 2022-11-08 1835.790039 1892.949951 1830.569946 1859.189941 317700.0
# 2022-11-09 1840.0 1882.339966 1830.069946 1865.819946 359500.0
# 2022-11-10 1946.859985 1955.300049 1916.400024 1946.51001 516200.0
# 2022-11-11 1936.310059 2033.380005 1936.310059 2015.77002 442800.0
# 2022-11-14 1996.51001 2019.52002 1974.01001 1979.25 415700.0
# 2022-11-15 2029.619995 2061.959961 1975.219971 2001.900024 411200.0
# 2022-11-16 2008.949951 2028.829956 1990.0 2013.780029 302500.0
# 2022-11-17 1960.920044 1972.449951 1902.459961 1940.76001 494900.0
# 2022-11-18 1959.77002 1972.199951 1925.5 1940.280029 306100.0
# ...

# %%
row.name.date()
# Out:
# datetime.date(2023, 1, 5)

# %%
a = [1,2, 3, 4, 5, 6]

# %%
a[:1]
# Out:
# [1]

# %%
for index, row in df.iterrows():

# %%
import sqlite3, config
connection = sqlite3.connect(config.DB_FILE)
connection.row_factory = sqlite3.Row
cursor = connection.cursor()

cursor.execute("""
    SELECT * FROM stock_price
""")
rows = cursor.fetchall()

# %%
for row in rows:
    print(row['date'])
# Out:
# 2022-11-01
# 2022-11-02
# 2022-11-03
# 2022-11-04
# 2022-11-07
# 2022-11-08
# 2022-11-09
# 2022-11-10
# 2022-11-11
# 2022-11-14
# 2022-11-15
# 2022-11-16
# 2022-11-17
# 2022-11-18
# 2022-11-21
# 2022-11-22
# 2022-11-23
# 2022-11-25
# 2022-11-28
# 2022-11-29
# 2022-11-30
# 2022-12-01
# 2022-12-02
# 2022-12-05
# 2022-12-06
# 2022-12-07
# 2022-12-08
# 2022-12-09
# 2022-12-12
# 2022-12-13
# 2022-12-14
# 2022-12-15
# 2022-12-16
# 2022-12-19
# 2022-12-20
# 2022-12-21
# 2022-12-22
# 2022-12-23
# 2022-12-27
# 2022-12-28
# 2022-12-29
# 2022-12-30
# 2023-01-03
# 2023-01-04
# 2023-01-05
# 2022-11-01
# 2022-11-02
# 2022-11-03
# 2022-11-04
# 2022-11-07
# 2022-11-08
# 2022-11-09
# 2022-11-10
# 2022-11-11
# 2022-11-14
# 2022-11-15
# 2022-11-16
# 2022-11-17
# 2022-11-18
# 2022-11-21
# 2022-11-22
# 2022-11-23
# 2022-11-25
# 2022-11-28
# 2022-11-29
# 2022-11-30
# 2022-12-01
# 2022-12-02
# 2022-12-05
# 2022-12-06
# 2022-12-07
# 2022-12-08
# 2022-12-09
# 2022-12-12
# 2022-12-13
# 2022-12-14
# ...
